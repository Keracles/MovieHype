# %% [markdown]
# ### Import des bibliothèques et du dataframe brut

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('total.csv', index_col=0)
df.head()
# Out:
#          date                                titre     budget    recette  \
# 0  2014-11-12                   Dumb and Dumber To   40000000  169837010
# 1  2004-11-11                                 Марс    2000000     240000
# 2  2014-01-22                      I, Frankenstein   65000000   76801179
# 3  2014-03-20  Captain America: The Winter Soldier  170000000  714766572
# 4  2013-09-11                            Vikingdom   15600000     747872
#
#    duree                                      genres  \
# 0    110                                  ['Comedy']
# 1    100                         ['Comedy', 'Drama']
# 2     92                      ['Horror', 'Thriller']
# 3    136  ['Action', 'Adventure', 'Science Fiction']
# 4    114                               ['Adventure']
#
#                                             synopsis  \
# 0  20 years since their first adventure, Lloyd an...
# 1  Somewhere deep, deep in Russia there is a town...
# 2  200 years after his shocking creation, Dr. Fra...
# 3  After the cataclysmic events in New York with ...
# 4  A warrior fleeing the violence of his past mus...
#
#                                              tagline  \
# 0  The average person uses 10% of their brain cap...
# 1                                                NaN
# 2  In the battle between good and evil, an immort...
# 3                                In heroes we trust.
# 4                                 Live by the Sword.
#
#                             realisateur  \
# 0  ['Bobby Farrelly', 'Peter Farrelly']
# 1                     ['Anna Melikyan']
# 2                                    []
# 3        ['Anthony Russo', 'Joe Russo']
# 4                                    []
#
#                                              casting  \
# 0  ['Jim Carrey', 'Jeff Daniels', 'Laurie Holden'...
# 1  ['Nana Kiknadze', 'Artur Smolyaninov', 'Yevgen...
# 2  ['Aaron Eckhart', 'Yvonne Strahovski', 'Bill N...
# 3  ['Chris Evans', 'Scarlett Johansson', 'Sebasti...
# 4  ['Dominic Purcell', 'Natassia Malthe', 'Craig ...
#
#                                compagnies_production  suite  \
# 0  ['New Line Cinema', 'Universal Pictures', 'Con...      3
# 1             ['Central Partnership', 'Studio SLON']      1
# 2  ['Lakeshore Entertainment', 'Sidney Kimmel Ent...      1
# 3                                 ['Marvel Studios']      2
# 4                                    ['KRU Studios']      1
#
#   production_countries       langues    imdb_id  vote_average  vote_count  \
# 0               ['US']        ['en']  tt2096672         5.542        2740
# 1               ['RU']        ['ru']  tt0417949         5.700           3
# 2         ['AU', 'US']        ['en']  tt1418377         5.272        1628
# 3               ['US']        ['en']  tt1843866         7.678       16638
# 4               ['MY']  ['en', 'zh']  tt1785669         4.380          54
#
#      status
# 0  Released
# 1  Released
# 2  Released
# 3  Released
# 4  Released

# %% [markdown]
# ### Fonction qui drop les colonnes qui ne nous servirons pas dans un premier temps

# %%
def drop_usless_columns(df):
    labels = ['synopsis', 'tagline', 'status', 'imdb_id']
    df_update = df.drop(labels, axis = 1)
    return df_update

# %%
df_update = drop_usless_columns(df)
df_update.head()
# Out:
#          date                                titre     budget    recette  \
# 0  2014-11-12                   Dumb and Dumber To   40000000  169837010
# 1  2004-11-11                                 Марс    2000000     240000
# 2  2014-01-22                      I, Frankenstein   65000000   76801179
# 3  2014-03-20  Captain America: The Winter Soldier  170000000  714766572
# 4  2013-09-11                            Vikingdom   15600000     747872
#
#    duree                                      genres  \
# 0    110                                  ['Comedy']
# 1    100                         ['Comedy', 'Drama']
# 2     92                      ['Horror', 'Thriller']
# 3    136  ['Action', 'Adventure', 'Science Fiction']
# 4    114                               ['Adventure']
#
#                             realisateur  \
# 0  ['Bobby Farrelly', 'Peter Farrelly']
# 1                     ['Anna Melikyan']
# 2                                    []
# 3        ['Anthony Russo', 'Joe Russo']
# 4                                    []
#
#                                              casting  \
# 0  ['Jim Carrey', 'Jeff Daniels', 'Laurie Holden'...
# 1  ['Nana Kiknadze', 'Artur Smolyaninov', 'Yevgen...
# 2  ['Aaron Eckhart', 'Yvonne Strahovski', 'Bill N...
# 3  ['Chris Evans', 'Scarlett Johansson', 'Sebasti...
# 4  ['Dominic Purcell', 'Natassia Malthe', 'Craig ...
#
#                                compagnies_production  suite  \
# 0  ['New Line Cinema', 'Universal Pictures', 'Con...      3
# 1             ['Central Partnership', 'Studio SLON']      1
# 2  ['Lakeshore Entertainment', 'Sidney Kimmel Ent...      1
# 3                                 ['Marvel Studios']      2
# 4                                    ['KRU Studios']      1
#
#   production_countries       langues  vote_average  vote_count
# 0               ['US']        ['en']         5.542        2740
# 1               ['RU']        ['ru']         5.700           3
# 2         ['AU', 'US']        ['en']         5.272        1628
# 3               ['US']        ['en']         7.678       16638
# 4               ['MY']  ['en', 'zh']         4.380          54

# %% [markdown]
# ### Fonction qui drop les lignes qui ont des colonnes vides

# %%
def drop_empty_lines(df):
    index_names = df[(df['budget'] == 0) | (df['recette'] <=0) | (df['duree'] == 0) | (df['genres'] == '[]') | (df['realisateur'] == '[]') | (df['casting'] == '[]') | (df['production_countries'] == '[]') | (df['langues'] == '[]')].index
    df_update_v2 = df.drop(index_names, axis = 0)
    df_update_v2.reset_index(drop = True, inplace = True)
    return df_update_v2

# %%
df_update_v2 = drop_empty_lines(df_update)
print(df_update_v2.shape[0])
df_update_v2.head()
# Out:
# 6899
#          date                                titre     budget    recette  \
# 0  2014-11-12                   Dumb and Dumber To   40000000  169837010
# 1  2004-11-11                                 Марс    2000000     240000
# 2  2014-03-20  Captain America: The Winter Soldier  170000000  714766572
# 3  2012-03-15                    Тот ещё Карлосон!    4000000    9938268
# 4  1976-04-05                        The Blue Bird   12000000     887000
#
#    duree                                       genres  \
# 0    110                                   ['Comedy']
# 1    100                          ['Comedy', 'Drama']
# 2    136   ['Action', 'Adventure', 'Science Fiction']
# 3     80              ['Comedy', 'Fantasy', 'Family']
# 4     95  ['Adventure', 'Family', 'Fantasy', 'Drama']
#
#                             realisateur  \
# 0  ['Bobby Farrelly', 'Peter Farrelly']
# 1                     ['Anna Melikyan']
# 2        ['Anthony Russo', 'Joe Russo']
# 3                  ['Sarik Andreasyan']
# 4                      ['George Cukor']
#
#                                              casting  \
# 0  ['Jim Carrey', 'Jeff Daniels', 'Laurie Holden'...
# 1  ['Nana Kiknadze', 'Artur Smolyaninov', 'Yevgen...
# 2  ['Chris Evans', 'Scarlett Johansson', 'Sebasti...
# 3  ['Mikhail Galustyan', 'Igor Vernik', 'Mariya S...
# 4  ['Elizabeth Taylor', 'Jane Fonda', 'Ava Gardne...
#
#                                compagnies_production  suite  \
# 0  ['New Line Cinema', 'Universal Pictures', 'Con...      3
# 1             ['Central Partnership', 'Studio SLON']      1
# 2                                 ['Marvel Studios']      2
# 3                                   ['Enjoy Movies']      1
# 4  ['20th Century Fox', 'Lenfilm', 'Sovinfilm', '...      1
#
#   production_countries langues  vote_average  vote_count
# 0               ['US']  ['en']         5.542        2740
# 1               ['RU']  ['ru']         5.700           3
# 2               ['US']  ['en']         7.678       16638
# 3               ['RU']  ['ru']         3.400          24
# 4         ['RU', 'US']  ['en']         6.000          25

# %% [markdown]
# ### Fonction qui transforme les string de liste en liste de string pour faciliter la manipulation

# %%
list_keys = ['genres', 'production_countries', 'realisateur', 'casting', 'compagnies_production', 'langues']

def str_to_list(df, key):
    df_new = df

    for k in key: #on parcourt les clés à modifier spécifiées en argument de la fonction

        for ind in range(df_new.shape[0]): #on parcourt toutes les lignes du Dataframe

            string = df_new[k].iloc[ind] #on récupère la valeur à modifier pour chaque ligne

            if type(string) == str : # on vérifie si c'est bien une string
                
                #création de la nouvelle variable de type liste qui remplacera l'ancienne

                liste_finale = []

                #remplissage de la variable de type liste en faisant des opérations sur la string

                list_string = string[1:-1].split(',')
                for i,j in enumerate(list_string):
                    if i == 0:
                        mot = j[1:-1]
                        if mot not in liste_finale:
                            liste_finale.append(mot)
                    else:
                        mot = j[2:-1]
                        if mot not in liste_finale:
                            liste_finale.append(mot)
                
                #affectation de la nouvelle valeur de type liste à l'élément modifié du Dataframe

                df_new.at[ind,k] = liste_finale
    
    df_new['date'] = pd.to_datetime(df_new['date'])

    return df_new

# %%
df_update_v3 = str_to_list(df_update_v2, list_keys)

# %% [markdown]
# ### Vérification de la cohérence des valeurs dans les colones aprés modification du dataframe

# %%
print(f"la quantité de données est : {df_update_v3.shape}")
print(f'nom des colones : {list(df_update_v3.columns)}')
for c in df_update_v3.columns:
    print(f"le format de {c} est : {df_update_v3[c].dtype}")
# Out:
# la quantité de données est : (6899, 14)
# nom des colones : ['date', 'titre', 'budget', 'recette', 'duree', 'genres', 'realisateur', 'casting', 'compagnies_production', 'suite', 'production_countries', 'langues', 'vote_average', 'vote_count']
# le format de date est : datetime64[ns]
# le format de titre est : object
# le format de budget est : int64
# le format de recette est : int64
# le format de duree est : int64
# le format de genres est : object
# le format de realisateur est : object
# le format de casting est : object
# le format de compagnies_production est : object
# le format de suite est : int64
# le format de production_countries est : object
# le format de langues est : object
# le format de vote_average est : float64
# le format de vote_count est : int64

# %% [markdown]
# ligne avec la date la plus récente

# %%
df_update_v3[df_update_v3.date == df_update_v3.date.max()]
# Out:
#            date              titre  budget  recette  duree             genres  \
# 6898 2022-12-23  No One Stays Good   16000    20000     70  [Drama, Thriller]
#
#              realisateur                                            casting  \
# 6898  [Antonio Cavallos]  [Cody Martin, Bryce Martin, Karla Martin, Rand...
#
#      compagnies_production  suite production_countries langues  vote_average  \
# 6898        [Impact Films]      1                 [US]    [en]           0.0
#
#       vote_count
# 6898           0

# %% [markdown]
# ligne avec la plus ancienne date

# %%
df_update_v3[df_update_v3.date == df_update_v3.date.min()]
# Out:
#            date             titre  budget  recette  duree          genres  \
# 6843 1913-11-24  Traffic in Souls    5700  1800000     88  [Crime, Drama]
#
#                 realisateur  \
# 6843  [George Loane Tucker]
#
#                                                 casting  \
# 6843  [Jane Gail, Ethel Grandin, William H. Turner, ...
#
#               compagnies_production  suite production_countries   langues  \
# 6843  [Independent Moving Pictures]      1                 [US]  [en, xx]
#
#       vote_average  vote_count
# 6843           5.5          17

# %% [markdown]
# tableau des lignes avec le plus grand et le plus petit budget

# %%
df_update_v3[(df_update_v3.budget == df_update_v3.budget.max()) | (df_update_v3.budget == df_update_v3.budget.min())]
# Out:
#            date                                              titre     budget  \
# 496  2011-05-14        Pirates of the Caribbean: On Stranger Tides  380000000
# 2612 2012-12-28                               Bojhena Shey Bojhena          1
# 2951 2003-01-01  Latham Entertainment Presents: An All New Come...          1
# 4277 2018-01-16                                      The Lucky Man          1
# 4611 1997-01-05                           Kys, kærlighed og kroner          1
# 5046 2016-07-29                                       Sesh Sangbad          1
# 5129 2015-12-04               Single Dad 2: A Single Dad Christmas          1
# 5515 2017-05-19                                    New York Masalı          1
# 5544 2019-07-09                                   Perfect, I Think          1
# 5633 1997-12-30                                       Little Ghost          1
# 5675 2019-04-21                                       Precognition          1
# 5676 2019-08-18                                  You're in Trouble          1
# 5677 2019-08-24                                            Assumed          1
# 5678 2019-08-25                          You Know What's Funny...?          1
# 5864 2020-02-17                                            Mothman          1
# 5865 2018-08-09                                             Malawi          1
# 5893 2020-06-19                                The Year of The Day          1
# 5942 2018-12-21                                             Friend          1
# 5943 2005-06-01                                       SobEncomenda          1
# 5944 2020-08-30                                          Me Within          1
# 5959 2020-08-24                                           Brothers          1
# 5980 2020-08-26                                     Is This Water?          1
# 5985 2020-10-15                                         Lipothymia          1
# 6026 2020-11-13                                Rocky Horror Remade          1
# 6056 2020-12-08                                    Childhood's End          1
# 6102 2019-11-22                                             PePePe          1
# 6311 2014-12-16                                Death of a Criminal          1
# 6323 2021-08-12                                              Limbo          1
# 6366 2021-04-12                                          A Way Out          1
# 6394 2021-08-27                                      Sara & Jaimie          1
# 6813 2021-09-02                                I was not murdered.          1
# 6880 2020-03-20                                        The Package          1
#
#          recette  duree                                             genres  \
# 496   1045713802    137                       [Adventure, Action, Fantasy]
# 2612          15    145                   [Drama, Family, Comedy, Romance]
# 2951          15     90                                           [Comedy]
# 4277          24     98                   [Action, Drama, Science Fiction]
# 4611           1     24                                    [Comedy, Drama]
# 5046           2    120                           [Drama, Thriller, Crime]
# 5129           3      2                                           [Comedy]
# 5515         500     99                                  [Romance, Comedy]
# 5544           1     10                                           [Comedy]
# 5633          14     90                       [Family, Fantasy, Adventure]
# 5675           1     20                 [Horror, Thriller, Drama, Mystery]
# 5676           1     25                                           [Comedy]
# 5677           1     32  [Science Fiction, Action, Crime, Drama, Myster...
# 5678           1     11                           [Comedy, Drama, Romance]
# 5864         123      3                                            [Drama]
# 5865         140     80                                      [Documentary]
# 5893           1      5                                            [Drama]
# 5942           1     37                            [Drama, Mystery, Crime]
# 5943           2     75                            [Crime, Comedy, Action]
# 5944           1      5                                   [Mystery, Drama]
# 5959           1     17                                            [Drama]
# 5980           2     11                     [Documentary, History, Family]
# 5985           1      9                                   [Drama, Mystery]
# 6026           1     95  [Horror, Animation, Music, Comedy, Science Fic...
# 6056           2     11                                            [Drama]
# 6102           1      6                                            [Drama]
# 6311           2      1                                            [Crime]
# 6323          30     10                                 [Action, Thriller]
# 6366           1      7                                            [Drama]
# 6394           1     14                                  [Romance, Comedy]
# 6813           1     82                                   [Drama, Mystery]
# 6880         100      3                        [Thriller, Mystery, Comedy]
#
#                          realisateur  \
# 496                   [Rob Marshall]
# 2612               [Raj Chakraborty]
# 2951                 [Jerry Gerrard]
# 4277        [Norman Gregory McGuire]
# 4611              [Louise Andreasen]
# 5046                  [Pallav Gupta]
# 5129                 [Ethan Johnson]
# 5515                 [Doğan Özmekik]
# 5544                   [Chelle Reik]
# 5633                  [Linda Shayne]
# 5675                  [Jesse Fraire]
# 5676               [Ricky Rodriguez]
# 5677               [Michael D. Head]
# 5678            [Carlos De La Torre]
# 5864                  [Ben McMorran]
# 5865                  [Ben McMorran]
# 5893                     [G.D Stami]
# 5942                    [Lukas Koch]
# 5943         [Thiago Amaral Ribeiro]
# 5944                     [G.D Stami]
# 5959                      [CZ Oster]
# 5980               [Craigen Z Oster]
# 5985            [Alex Trincado Haro]
# 6026                  [Katie Palino]
# 6056                  [Lewis Newman]
# 6102                 [Ricky Gunarto]
# 6311                 [Titus Meadows]
# 6323  [Lachlan Evans, Kacper Siwiak]
# 6366                   [Ahmed Nazif]
# 6394             [Nicole Toporowski]
# 6813                    [Adam Hobbs]
# 6880                  [Arman Taheri]
#
#                                                 casting  \
# 496   [Johnny Depp, Penélope Cruz, Geoffrey Rush, Ia...
# 2612  [Soham Chakraborty, Mimi Chakraborty, Abir Cha...
# 2951  [Sommore, Bruce Bruce, J. Anthony Brown, Earth...
# 4277  [Jesse James, Mariana Paola Vicente, Burton Gi...
# 4611  [Peter Reichhardt, Trine Dyrholm, Ulrich Thomsen]
# 5046  [Srabanti Chatterjee, Moushumi Chaterjee, Part...
# 5129                                       [Rayce Cook]
# 5515  [Esin Varan, Ahmet Bodur, Ekin Türkmen, Derya ...
# 5544  [Rhys Smith, Hannah Schroter, David Campbell, ...
# 5633  [Kristina Wayborn, Jim Fitzpatrick, Sally Kirk...
# 5675  [Tessa Leigh Mauer, Sherrie Prose, Greg Thomps...
# 5676  [Alberto Orozco, Alexis Solano, Alfredo Sanche...
# 5677  [Julian Cavett, Jerry Walker, Alfredo Sanchez,...
# 5678  [Valerie Santos, Jon Erik Castro, Jesse Fraire...
# 5864                      [David Hall, Stuart McMorran]
# 5865                      [Finlay Rutter, James Walker]
# 5893                                           [Doomer]
# 5942  [Svenja Theivogt, Lisann Klapp, Daniel Hald, S...
# 5943  [Sanderson Mariquito, Hudson Cotta, Rodrigo Ol...
# 5944                                 [Dylan Anaya, Imi]
# 5959  [Thomas Brumfield, Andrew Brumfield, Brumfield...
# 5980  [Nicole Toporowski, Thomas Brumfield, Final Cu...
# 5985                         [Jana Punsola, Carla Dolç]
# 6026  [Courtney Archard, Luisa Baldino, Zoe Bell, Au...
# 6056                                     [Matty Turner]
# 6102        [Ricky Gunarto, Daniel, Vincensius, Debora]
# 6311                                    [Titus Meadows]
# 6323                  [Sachin Badrakia, Moutasam Kahin]
# 6366                                      [Anas Alhajj]
# 6394                    [Victor Anderson, Sophia Brown]
# 6813  [Henry Austin, Haman Kallaveh, Katie Carey, El...
# 6880                       [Atossa Alavi, Kimya Taheri]
#
#                                   compagnies_production  suite  \
# 496   [Walt Disney Pictures, Jerry Bruckheimer Films...      4
# 2612                                [SVF Entertainment]      1
# 2951                             [Latham Entertainment]      1
# 4277                                     [Lucky Film, ]      1
# 4611               [M&M Productions, Dansk Novellefilm]      1
# 5046                                         [Eros Now]      1
# 5129                                      [Twat Kicker]      1
# 5515                                                 []      1
# 5544                                [Nonya Productions]      1
# 5633             [Castel Film, Full Moon Entertainment]      1
# 5675  [Tower Productions, JonGon Productions, J. Fri...      1
# 5676                                [Tower Productions]      1
# 5677                                [Tower Productions]      1
# 5678                                [Tower Productions]      1
# 5864                                      [BAM Studios]      1
# 5865                                      [BAM Studios]      1
# 5893                                        [G.D Stami]      1
# 5942                                      [Theory Arts]      1
# 5943                                    [Javali Filmes]      1
# 5944                                        [G.D Stami]      1
# 5959                         [Love Streams Productions]      1
# 5980                         [Love Streams Productions]      1
# 5985                                [Sotos Productions]      1
# 6026                             [The Player's Society]      1
# 6056                                                 []      1
# 6102                                            [ricky]      1
# 6311                            [Macho Man Productions]      1
# 6323                                                 []      1
# 6366                                          [Blushot]      1
# 6394                               [Love Streams Films]      1
# 6813                                   [Hobnob Studios]      1
# 6880                                   [Taheri Studios]      1
#
#      production_countries       langues  vote_average  vote_count
# 496              [GB, US]      [en, es]         6.527       12361
# 2612                 [IN]          [bn]         7.500          12
# 2951                 [US]          [en]         0.000           0
# 4277                 [US]  [en, es, el]         6.200           8
# 4611                 [DK]          [da]         6.000           1
# 5046                 [IN]          [bn]         0.000           0
# 5129                 [US]          [en]        10.000           1
# 5515                 [TR]          [tr]         1.000           1
# 5544                 [US]          [en]         0.000           0
# 5633             [RO, US]          [en]         6.100           7
# 5675                 [US]          [en]         0.000           0
# 5676                 [US]          [en]         0.000           0
# 5677                 [US]          [en]         0.000           0
# 5678                 [US]      [en, es]         0.000           0
# 5864                 [GB]          [en]         9.000           3
# 5865             [MW, GB]          [en]        10.000           2
# 5893                 [IN]          [en]         0.000           0
# 5942                 [DE]          [de]        10.000           1
# 5943                 [BR]          [pt]        10.000           1
# 5944                 [IN]          [en]         0.000           0
# 5959                 [US]          [en]         0.000           0
# 5980                 [US]          [en]         0.000           0
# 5985                 [ES]          [ca]        10.000           2
# 6026                 [US]          [en]        10.000           1
# 6056                 [GB]          [en]         0.000           0
# 6102                 [ID]          [id]         7.000           1
# 6311                 [US]          [is]         0.000           0
# 6323                 [GB]          [en]         0.000           0
# 6366                 [EG]      [ar, en]         9.000           1
# 6394                 [US]          [en]         0.000           0
# 6813                 [GB]          [en]         0.000           0
# 6880                 [US]          [en]         0.000           0

# %% [markdown]
# tableau avec la plus grande et la plus petite recette

# %%
df_update_v3[(df_update_v3.recette == df_update_v3.recette.max()) | (df_update_v3.recette == df_update_v3.recette.min())]
# Out:
#            date                                        titre     budget  \
# 1686 2009-12-15                                       Avatar  237000000
# 2986 2014-11-21                          Naaigal Jaakirathai     630000
# 3453 2000-08-11                   MVP: Most Valuable Primate          4
# 3831 2015-09-25  Head Full of Dreams, Heart Full of Promises        100
# 3990 2016-02-06                           ZERO Beyond Limits       1560
# 4611 1997-01-05                     Kys, kærlighed og kroner          1
# 5197 2015-05-30                                         Soap      10000
# 5544 2019-07-09                             Perfect, I Think          1
# 5675 2019-04-21                                 Precognition          1
# 5676 2019-08-18                            You're in Trouble          1
# 5677 2019-08-24                                      Assumed          1
# 5678 2019-08-25                    You Know What's Funny...?          1
# 5757 2014-10-16                       Clouded - A Conspiracy        500
# 5893 2020-06-19                          The Year of The Day          1
# 5942 2018-12-21                                       Friend          1
# 5944 2020-08-30                                    Me Within          1
# 5959 2020-08-24                                     Brothers          1
# 5985 2020-10-15                                   Lipothymia          1
# 6026 2020-11-13                          Rocky Horror Remade          1
# 6102 2019-11-22                                       PePePe          1
# 6266 2021-03-27                               Life and Death         10
# 6366 2021-04-12                                    A Way Out          1
# 6394 2021-08-27                                Sara & Jaimie          1
# 6429 2021-04-21                                    Pulsating        100
# 6787 2021-11-13                              My Dear Spectre        500
# 6798 2021-12-10                                     Monster?        100
# 6813 2021-09-02                          I was not murdered.          1
# 6814 2020-10-31                               Privacy Breach         10
# 6816 2021-12-23                  The Fright Before Christmas         10
# 6831 2021-03-09               The 4.5 'Flim On Film' Podcast         20
# 6856 2022-02-04                                The Interview          5
# 6895 2015-01-22                         Jeff Movie 3: Part 1         10
#
#          recette  duree                                             genres  \
# 1686  2920357254    162      [Action, Adventure, Fantasy, Science Fiction]
# 2986           1    126                         [Thriller, Action, Comedy]
# 3453           1     85                                   [Comedy, Family]
# 3831           1     10                                      [Documentary]
# 3990           1     60                 [Action, Adventure, Comedy, Crime]
# 4611           1     24                                    [Comedy, Drama]
# 5197           1     16                                    [Comedy, Drama]
# 5544           1     10                                           [Comedy]
# 5675           1     20                 [Horror, Thriller, Drama, Mystery]
# 5676           1     25                                           [Comedy]
# 5677           1     32  [Science Fiction, Action, Crime, Drama, Myster...
# 5678           1     11                           [Comedy, Drama, Romance]
# 5757           1     59                                           [Comedy]
# 5893           1      5                                            [Drama]
# 5942           1     37                            [Drama, Mystery, Crime]
# 5944           1      5                                   [Mystery, Drama]
# 5959           1     17                                            [Drama]
# 5985           1      9                                   [Drama, Mystery]
# 6026           1     95  [Horror, Animation, Music, Comedy, Science Fic...
# 6102           1      6                                            [Drama]
# 6266           1      9                                 [Comedy, Thriller]
# 6366           1      7                                            [Drama]
# 6394           1     14                                  [Romance, Comedy]
# 6429           1      4                  [Thriller, Drama, Music, Mystery]
# 6787           1      6                                   [Romance, Drama]
# 6798           1      9                           [Horror, Romance, Drama]
# 6813           1     82                                   [Drama, Mystery]
# 6814           1      3  [Science Fiction, Action, Adventure, Crime, Dr...
# 6816           1      3                                         [Thriller]
# 6831           1     51                                           [Comedy]
# 6856           1      2                                    [Comedy, Drama]
# 6895           1      2                                 [Thriller, Action]
#
#                                             realisateur  \
# 1686                                    [James Cameron]
# 2986                             [Shakti Soundar Rajan]
# 3453                                     [Robert Vince]
# 3831                                        [Renny Ray]
# 3990                                     [Beis Shabani]
# 4611                                 [Louise Andreasen]
# 5197                                [Christopher Brown]
# 5544                                      [Chelle Reik]
# 5675                                     [Jesse Fraire]
# 5676                                  [Ricky Rodriguez]
# 5677                                  [Michael D. Head]
# 5678                               [Carlos De La Torre]
# 5757                                 [Arden Cvitanovic]
# 5893                                        [G.D Stami]
# 5942                                       [Lukas Koch]
# 5944                                        [G.D Stami]
# 5959                                         [CZ Oster]
# 5985                               [Alex Trincado Haro]
# 6026                                     [Katie Palino]
# 6102                                    [Ricky Gunarto]
# 6266                                    [SirChancealot]
# 6366                                      [Ahmed Nazif]
# 6394                                [Nicole Toporowski]
# 6429                                    [Nathan Cowles]
# 6787                              [M. Ridzky Ramadhani]
# 6798                                   [Brinceton Baum]
# 6813                                       [Adam Hobbs]
# 6814                                           [Josh N]
# 6816  [Maryn Zaborowsky, Trever Capien, Lily William...
# 6831                                    [James Horsley]
# 6856                                      [Camdan Mead]
# 6895                                      [Jack McGurn]
#
#                                                 casting  \
# 1686  [Sam Worthington, Zoe Saldaña, Sigourney Weave...
# 2986  [Sibiraj, Arundhathi Nair, Manobala, Balaji Pa...
# 3453  [Kevin Zegers, Jamie Renée Smith, Alexa Benett...
# 3831  [Inna Levian, Alise Sheli Orsa, Davek, Denis K...
# 3990  [Marigon Zyberi, Valenti Shabani, Siok Tosuni,...
# 4611  [Peter Reichhardt, Trine Dyrholm, Ulrich Thomsen]
# 5197         [Eugenia Caruso, Roy Finn, David J. Keogh]
# 5544  [Rhys Smith, Hannah Schroter, David Campbell, ...
# 5675  [Tessa Leigh Mauer, Sherrie Prose, Greg Thomps...
# 5676  [Alberto Orozco, Alexis Solano, Alfredo Sanche...
# 5677  [Julian Cavett, Jerry Walker, Alfredo Sanchez,...
# 5678  [Valerie Santos, Jon Erik Castro, Jesse Fraire...
# 5757                                       [Shane Amin]
# 5893                                           [Doomer]
# 5942  [Svenja Theivogt, Lisann Klapp, Daniel Hald, S...
# 5944                                 [Dylan Anaya, Imi]
# 5959  [Thomas Brumfield, Andrew Brumfield, Brumfield...
# 5985                         [Jana Punsola, Carla Dolç]
# 6026  [Courtney Archard, Luisa Baldino, Zoe Bell, Au...
# 6102        [Ricky Gunarto, Daniel, Vincensius, Debora]
# 6266  [Emery Gischler, SirChancealot, Connor (from S...
# 6366                                      [Anas Alhajj]
# 6394                    [Victor Anderson, Sophia Brown]
# 6429                                   [Jordan Belcher]
# 6787                                     [Tamara Putri]
# 6798                        [Juan Suarez, Olivia Watts]
# 6813  [Henry Austin, Haman Kallaveh, Katie Carey, El...
# 6814  [Henri L, Ethan N, Josh M, Charlie R, Hugh H, ...
# 6816  [Maryn Zaborowsky, Trever Capien, Lily William...
# 6831  [Patrick Monahan, James Horsley, Guy Barnsley,...
# 6856                     [Chloe Braatz, Katie Cambpell]
# 6895  [Jeff T. Ball, Matthew Stewart, Ewan Macfarlan...
#
#                                   compagnies_production  suite  \
# 1686  [20th Century Fox, Ingenious Media, Dune Enter...      4
# 2986                           [Nathambal Film Factory]      1
# 3453  [Keystone Family Pictures, Funky Monkey Produc...      1
# 3831                             [Art Attack Manifesto]      1
# 3990                                [SEHR, Aceldoredon]      1
# 4611               [M&M Productions, Dansk Novellefilm]      1
# 5197                                                 []      1
# 5544                                [Nonya Productions]      1
# 5675  [Tower Productions, JonGon Productions, J. Fri...      1
# 5676                                [Tower Productions]      1
# 5677                                [Tower Productions]      1
# 5678                                [Tower Productions]      1
# 5757                                                 []      1
# 5893                                        [G.D Stami]      1
# 5942                                      [Theory Arts]      1
# 5944                                        [G.D Stami]      1
# 5959                         [Love Streams Productions]      1
# 5985                                [Sotos Productions]      1
# 6026                             [The Player's Society]      1
# 6102                                            [ricky]      1
# 6266                      [Wandering Robot Productions]      1
# 6366                                          [Blushot]      1
# 6394                               [Love Streams Films]      1
# 6429                               [The Boys of Willow]      1
# 6787                                [Parcstar Assembly]      1
# 6798                                 [Brinceton Vision]      1
# 6813                                   [Hobnob Studios]      1
# 6814                                                 []      1
# 6816                                           [iMovie]      1
# 6831                           [Colourline Productions]      1
# 6856                                      [Warren Tech]      1
# 6895                                 [One Sock Wonders]      1
#
#      production_countries       langues  vote_average  vote_count
# 1686             [US, GB]      [en, es]         7.526       26386
# 2986                 [IN]          [ta]         6.700           7
# 3453             [CA, US]          [en]         4.800          67
# 3831             [CZ, IN]      [en, ur]        10.000           1
# 3990                 [AL]  [sq, en, ja]        10.000           1
# 4611                 [DK]          [da]         6.000           1
# 5197                 [GB]          [en]        10.000           1
# 5544                 [US]          [en]         0.000           0
# 5675                 [US]          [en]         0.000           0
# 5676                 [US]          [en]         0.000           0
# 5677                 [US]          [en]         0.000           0
# 5678                 [US]      [en, es]         0.000           0
# 5757                 [AU]          [en]         0.000           0
# 5893                 [IN]          [en]         0.000           0
# 5942                 [DE]          [de]        10.000           1
# 5944                 [IN]          [en]         0.000           0
# 5959                 [US]          [en]         0.000           0
# 5985                 [ES]          [ca]        10.000           2
# 6026                 [US]          [en]        10.000           1
# 6102                 [ID]          [id]         7.000           1
# 6266                 [US]          [en]         0.000           0
# 6366                 [EG]      [ar, en]         9.000           1
# 6394                 [US]          [en]         0.000           0
# 6429                 [US]          [en]         0.000           0
# 6787                 [ID]          [en]         9.000           1
# 6798                 [US]          [en]         0.000           0
# 6813                 [GB]          [en]         0.000           0
# 6814                 [NZ]          [en]        10.000           2
# 6816                 [US]          [en]        10.000           1
# 6831                 [GB]          [en]         0.000           0
# 6856                 [US]          [en]        10.000           1
# 6895                 [GB]          [en]         9.000           1

# %%
df_update_v3[(df_update_v3.duree == df_update_v3.duree.max()) | (df_update_v3.duree == df_update_v3.duree.min())]
# Out:
#            date                                             titre    budget  \
# 4409 2010-07-07                                            Carlos  18000000
# 5008 2000-01-01                                     Le savon lave      2883
# 5686 2019-10-31                             Cómo regar un girasol        50
# 6311 2014-12-16                               Death of a Criminal         1
# 6428 1998-02-03                        Science Please! : The Wind         3
# 6433 2001-10-01                              Why Is the Sky Blue?      7027
# 6434 2001-01-01                                              Fire      5032
# 6772 2000-01-01  Science Please! : The Internal Combustion Engine    300996
# 6773 1998-01-01              Science Please! : The Force of Water     43134
# 6774 1998-01-01            Science Please! : Wheel Meets Friction      5477
# 6850 2019-07-15                                             Homer        80
# 6857 2020-02-09                           Where can I buy a mask?      2000
#
#       recette  duree                             genres  \
# 4409   871279    339  [Crime, Drama, Thriller, History]
# 5008     2883      1                [Animation, Family]
# 5686      150      1                          [Fantasy]
# 6311        2      1                            [Crime]
# 6428        3      1                [Family, Animation]
# 6433     7027      1         [Animation, Family, Music]
# 6434     5032      1                [Animation, Comedy]
# 6772   300996      1                        [Animation]
# 6773    43134      1                        [Animation]
# 6774     5477      1                        [Animation]
# 6850       10      1                [Comedy, Animation]
# 6857       10      1                            [Music]
#
#                           realisateur  \
# 4409                [Olivier Assayas]
# 5008            [Sylvain Charbonneau]
# 5686                 [Joaquín Cariño]
# 6311                  [Titus Meadows]
# 6428  [Claude Cloutier, Martin Barry]
# 6433            [Sylvain Charbonneau]
# 6434            [Sylvain Charbonneau]
# 6772                [Claude Cloutier]
# 6773                [Claude Cloutier]
# 6774                [Claude Cloutier]
# 6850               [Gustavo Riquelme]
# 6857                      [Yin Woods]
#
#                                                 casting  \
# 4409  [Edgar Ramírez, Alexander Scheer, Nora Waldstä...
# 5008                                       [Rick Jones]
# 5686                                  [Aldair Enríquez]
# 6311                                    [Titus Meadows]
# 6428                                       [Rick Jones]
# 6433                                       [Rick Jones]
# 6434                                       [Rick Jones]
# 6772                                       [Rick Jones]
# 6773                                       [Rick Jones]
# 6774                                       [Rick Jones]
# 6850                                 [Gustavo Riquelme]
# 6857  [Winnie Wong Wing Yan, Czarina Yeung, Hyman Hu...
#
#                                   compagnies_production  suite  \
# 4409  [ARTE France Cinéma, Canal+, CNC, PROCIREP, St...      1
# 5008                                        [ONF | NFB]      1
# 5686                  [ESPERA Y DESESPERA Espectáculos]      1
# 6311                            [Macho Man Productions]      1
# 6428                                        [ONF | NFB]      1
# 6433                                        [ONF | NFB]      1
# 6434                                        [ONF | NFB]      1
# 6772                                        [ONF | NFB]      1
# 6773                                        [ONF | NFB]      1
# 6774                                        [ONF | NFB]      1
# 6850                                [The Amazing Brick]      1
# 6857                                                 []      1
#
#      production_countries                           langues  vote_average  \
# 4409             [DE, FR]  [fr, de, en, es, ar, hu, ja, ru]         6.981
# 5008                 [CA]                              [en]        10.000
# 5686                 [MX]                              [es]        10.000
# 6311                 [US]                              [is]         0.000
# 6428                 [CA]                              [en]        10.000
# 6433                 [CA]                              [en]        10.000
# 6434                 [CA]                              [en]         0.000
# 6772                 [CA]                              [en]         0.000
# 6773                 [CA]                              [en]         0.000
# 6774                 [CA]                              [en]         0.000
# 6850             [CL, US]                              [en]         0.000
# 6857                 [US]  [cn, en, fr, de, hi, ja, ko, th]         9.000
#
#       vote_count
# 4409         156
# 5008           1
# 5686           1
# 6311           0
# 6428           1
# 6433           1
# 6434           0
# 6772           0
# 6773           0
# 6774           0
# 6850           0
# 6857           1

# %%
def drop_useless_lines(df):
    index_names = df[(df['budget'] < 300000) | (df['recette'] < 300000) | (df['duree'] < 60) | (df_update_v3['casting'].map(len) < 1) | (df_update_v3['date'] < pd.to_datetime('2000-01-01')) | (df_update_v3['date'] > pd.to_datetime('2022-10-13'))].index
    df_update_v4 = df.drop(index_names, axis = 0)
    df_update_v4.reset_index(drop = True, inplace = True)
    return df_update_v4

# %%
df_update_v4 = drop_useless_lines(df_update_v3)
print(df_update_v4.shape)
df_update_v4.head()
# Out:
# (3647, 14)
#         date                                titre     budget    recette  \
# 0 2014-11-12                   Dumb and Dumber To   40000000  169837010
# 1 2014-03-20  Captain America: The Winter Soldier  170000000  714766572
# 2 2012-03-15                    Тот ещё Карлосон!    4000000    9938268
# 3 2006-05-19                          See No Evil    8000000   18707966
# 4 2003-10-23                         Brother Bear  128000000  250397798
#
#    duree                                genres  \
# 0    110                              [Comedy]
# 1    136  [Action, Adventure, Science Fiction]
# 2     80             [Comedy, Fantasy, Family]
# 3     84                    [Horror, Thriller]
# 4     85        [Adventure, Animation, Family]
#
#                         realisateur  \
# 0  [Bobby Farrelly, Peter Farrelly]
# 1        [Anthony Russo, Joe Russo]
# 2                [Sarik Andreasyan]
# 3                    [Gregory Dark]
# 4     [Aaron Blaise, Robert Walker]
#
#                                              casting  \
# 0  [Jim Carrey, Jeff Daniels, Laurie Holden, Rach...
# 1  [Chris Evans, Scarlett Johansson, Sebastian St...
# 2  [Mikhail Galustyan, Igor Vernik, Mariya Semkin...
# 3  [Glenn Jacobs, Christina Vidal, Luke Pegler, C...
# 4  [Joaquin Phoenix, Jeremy Suarez, Jason Raize, ...
#
#                                compagnies_production  suite  \
# 0  [New Line Cinema, Universal Pictures, Conundru...      3
# 1                                   [Marvel Studios]      2
# 2                                     [Enjoy Movies]      1
# 3                    [Lions Gate Films, WWE Studios]      1
# 4                    [Walt Disney Feature Animation]      1
#
#   production_countries       langues  vote_average  vote_count
# 0                 [US]          [en]         5.542        2740
# 1                 [US]          [en]         7.678       16638
# 2                 [RU]          [ru]         3.400          24
# 3             [AU, US]          [en]         5.400         530
# 4                 [US]  [hr, en, iu]         7.244        4661

# %%
df_update_v4.to_csv("data\df_update_v4.csv")

# %% [markdown]
# ### Fonction qui permet de transformer les noms des genres en numéro

# %%
liste_genres = ['Comedy', 'Drama', 'Horror', 'Thriller', 'Action', 'Adventure', 'Science Fiction', 'Fantasy', 'Family', 'Crime', 'Romance', 'Mystery', 'Animation', 'War', 'Music', 'Western', 'History', 'Documentary', 'TV Movie']
liste_nb = range(len(liste_genres))
dico_genre = {'genres' : liste_genres, 'genre_number' : liste_nb}
dataset_genres = pd.DataFrame (dico_genre, index = liste_nb)
dataset_genres.head()
# Out:
#      genres  genre_number
# 0    Comedy             0
# 1     Drama             1
# 2    Horror             2
# 3  Thriller             3
# 4    Action             4

# %% [markdown]
# ### Fonction qui ajoute une colonne par genres

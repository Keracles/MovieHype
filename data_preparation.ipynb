# %% [markdown]
# ### Import des bibliothèques et du dataframe brut

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('total.csv', index_col=0)
df.head()
# Out:
#          date                                titre     budget    recette  \
# 0  2014-11-12                   Dumb and Dumber To   40000000  169837010
# 1  2004-11-11                                 Марс    2000000     240000
# 2  2014-01-22                      I, Frankenstein   65000000   76801179
# 3  2014-03-20  Captain America: The Winter Soldier  170000000  714766572
# 4  2013-09-11                            Vikingdom   15600000     747872
#
#    duree                                      genres  \
# 0    110                                  ['Comedy']
# 1    100                         ['Comedy', 'Drama']
# 2     92                      ['Horror', 'Thriller']
# 3    136  ['Action', 'Adventure', 'Science Fiction']
# 4    114                               ['Adventure']
#
#                                             synopsis  \
# 0  20 years since their first adventure, Lloyd an...
# 1  Somewhere deep, deep in Russia there is a town...
# 2  200 years after his shocking creation, Dr. Fra...
# 3  After the cataclysmic events in New York with ...
# 4  A warrior fleeing the violence of his past mus...
#
#                                              tagline  \
# 0  The average person uses 10% of their brain cap...
# 1                                                NaN
# 2  In the battle between good and evil, an immort...
# 3                                In heroes we trust.
# 4                                 Live by the Sword.
#
#                             realisateur  \
# 0  ['Bobby Farrelly', 'Peter Farrelly']
# 1                     ['Anna Melikyan']
# 2                                    []
# 3        ['Anthony Russo', 'Joe Russo']
# 4                                    []
#
#                                              casting  \
# 0  ['Jim Carrey', 'Jeff Daniels', 'Laurie Holden'...
# 1  ['Nana Kiknadze', 'Artur Smolyaninov', 'Yevgen...
# 2  ['Aaron Eckhart', 'Yvonne Strahovski', 'Bill N...
# 3  ['Chris Evans', 'Scarlett Johansson', 'Sebasti...
# 4  ['Dominic Purcell', 'Natassia Malthe', 'Craig ...
#
#                                compagnies_production  suite  \
# 0  ['New Line Cinema', 'Universal Pictures', 'Con...      3
# 1             ['Central Partnership', 'Studio SLON']      1
# 2  ['Lakeshore Entertainment', 'Sidney Kimmel Ent...      1
# 3                                 ['Marvel Studios']      2
# 4                                    ['KRU Studios']      1
#
#   production_countries       langues    imdb_id  vote_average  vote_count  \
# 0               ['US']        ['en']  tt2096672         5.542        2740
# 1               ['RU']        ['ru']  tt0417949         5.700           3
# 2         ['AU', 'US']        ['en']  tt1418377         5.272        1628
# 3               ['US']        ['en']  tt1843866         7.678       16638
# 4               ['MY']  ['en', 'zh']  tt1785669         4.380          54
#
#      status
# 0  Released
# 1  Released
# 2  Released
# 3  Released
# 4  Released

# %% [markdown]
# ### Fonction qui drop les colonnes qui ne nous servirons pas dans un premier temps

# %%
def drop_usless_columns(df):
    labels = ['synopsis', 'tagline', 'status', 'imdb_id']
    df_update = df.drop(labels, axis = 1)
    return df_update

# %%
df_update = drop_usless_columns(df)
df_update.head()
# Out:
#          date                                titre     budget    recette  \
# 0  2014-11-12                   Dumb and Dumber To   40000000  169837010
# 1  2004-11-11                                 Марс    2000000     240000
# 2  2014-01-22                      I, Frankenstein   65000000   76801179
# 3  2014-03-20  Captain America: The Winter Soldier  170000000  714766572
# 4  2013-09-11                            Vikingdom   15600000     747872
#
#    duree                                      genres  \
# 0    110                                  ['Comedy']
# 1    100                         ['Comedy', 'Drama']
# 2     92                      ['Horror', 'Thriller']
# 3    136  ['Action', 'Adventure', 'Science Fiction']
# 4    114                               ['Adventure']
#
#                             realisateur  \
# 0  ['Bobby Farrelly', 'Peter Farrelly']
# 1                     ['Anna Melikyan']
# 2                                    []
# 3        ['Anthony Russo', 'Joe Russo']
# 4                                    []
#
#                                              casting  \
# 0  ['Jim Carrey', 'Jeff Daniels', 'Laurie Holden'...
# 1  ['Nana Kiknadze', 'Artur Smolyaninov', 'Yevgen...
# 2  ['Aaron Eckhart', 'Yvonne Strahovski', 'Bill N...
# 3  ['Chris Evans', 'Scarlett Johansson', 'Sebasti...
# 4  ['Dominic Purcell', 'Natassia Malthe', 'Craig ...
#
#                                compagnies_production  suite  \
# 0  ['New Line Cinema', 'Universal Pictures', 'Con...      3
# 1             ['Central Partnership', 'Studio SLON']      1
# 2  ['Lakeshore Entertainment', 'Sidney Kimmel Ent...      1
# 3                                 ['Marvel Studios']      2
# 4                                    ['KRU Studios']      1
#
#   production_countries       langues  vote_average  vote_count
# 0               ['US']        ['en']         5.542        2740
# 1               ['RU']        ['ru']         5.700           3
# 2         ['AU', 'US']        ['en']         5.272        1628
# 3               ['US']        ['en']         7.678       16638
# 4               ['MY']  ['en', 'zh']         4.380          54

# %% [markdown]
# ### Fonction qui drop les lignes qui ont des colonnes vides

# %%
def drop_empty_lines(df):
    index_names = df[(df['budget'] == 0) | (df['recette'] <=0) | (df['duree'] == 0) | (df['genres'] == '[]') | (df['realisateur'] == '[]') | (df['casting'] == '[]') | (df['compagnies_production'] == '[]') | (df['production_countries'] == '[]') | (df['langues'] == '[]')].index
    df_update_v2 = df.drop(index_names, axis = 0)
    df_update_v2.reset_index(drop = True, inplace = True)
    return df_update_v2

# %%
df_update_v2 = drop_empty_lines(df_update)
print(df_update_v2.shape[0])
df_update_v2.head()
# Out:
# 6675
#          date                                titre     budget    recette  \
# 0  2014-11-12                   Dumb and Dumber To   40000000  169837010
# 1  2004-11-11                                 Марс    2000000     240000
# 2  2014-03-20  Captain America: The Winter Soldier  170000000  714766572
# 3  2012-03-15                    Тот ещё Карлосон!    4000000    9938268
# 4  1976-04-05                        The Blue Bird   12000000     887000
#
#    duree                                       genres  \
# 0    110                                   ['Comedy']
# 1    100                          ['Comedy', 'Drama']
# 2    136   ['Action', 'Adventure', 'Science Fiction']
# 3     80              ['Comedy', 'Fantasy', 'Family']
# 4     95  ['Adventure', 'Family', 'Fantasy', 'Drama']
#
#                             realisateur  \
# 0  ['Bobby Farrelly', 'Peter Farrelly']
# 1                     ['Anna Melikyan']
# 2        ['Anthony Russo', 'Joe Russo']
# 3                  ['Sarik Andreasyan']
# 4                      ['George Cukor']
#
#                                              casting  \
# 0  ['Jim Carrey', 'Jeff Daniels', 'Laurie Holden'...
# 1  ['Nana Kiknadze', 'Artur Smolyaninov', 'Yevgen...
# 2  ['Chris Evans', 'Scarlett Johansson', 'Sebasti...
# 3  ['Mikhail Galustyan', 'Igor Vernik', 'Mariya S...
# 4  ['Elizabeth Taylor', 'Jane Fonda', 'Ava Gardne...
#
#                                compagnies_production  suite  \
# 0  ['New Line Cinema', 'Universal Pictures', 'Con...      3
# 1             ['Central Partnership', 'Studio SLON']      1
# 2                                 ['Marvel Studios']      2
# 3                                   ['Enjoy Movies']      1
# 4  ['20th Century Fox', 'Lenfilm', 'Sovinfilm', '...      1
#
#   production_countries langues  vote_average  vote_count
# 0               ['US']  ['en']         5.542        2740
# 1               ['RU']  ['ru']         5.700           3
# 2               ['US']  ['en']         7.678       16638
# 3               ['RU']  ['ru']         3.400          24
# 4         ['RU', 'US']  ['en']         6.000          25

# %% [markdown]
# ### Fonction qui transforme les string de liste en liste de string pour faciliter la manipulation

# %%
list_keys = ['genres', 'production_countries', 'realisateur', 'casting', 'compagnies_production', 'langues']

def str_to_list(df, key):
    df_new = df

    for k in key: #on parcourt les clés à modifier spécifiées en argument de la fonction

        for ind in range(df_new.shape[0]): #on parcourt toutes les lignes du Dataframe

            string = df_new[k].iloc[ind] #on récupère la valeur à modifier pour chaque ligne

            if type(string) == str : # on vérifie si c'est bien une string
                
                #création de la nouvelle variable de type liste qui remplacera l'ancienne

                liste_finale = []

                #remplissage de la variable de type liste en faisant des opérations sur la string

                list_string = string[1:-1].split(',')
                for i,j in enumerate(list_string):
                    if i == 0:
                        mot = j[1:-1]
                        if mot not in liste_finale:
                            liste_finale.append(mot)
                    else:
                        mot = j[2:-1]
                        if mot not in liste_finale:
                            liste_finale.append(mot)
                
                #affectation de la nouvelle valeur de type liste à l'élément modifié du Dataframe

                df_new.at[ind,k] = liste_finale
    
    df_new['date'] = pd.to_datetime(df_new['date'])

    return df_new

# %%
df_update_v3 = str_to_list(df_update_v2, list_keys)

# %% [markdown]
# ### Vérification de la cohérence des valeurs dans les colones aprés modification du dataframe

# %%
print(f"la quantité de données est : {df_update_v3.shape}")
print(f'nom des colones : {list(df_update_v3.columns)}')
for c in df_update_v3.columns:
    print(f"le format de {c} est : {df_update_v3[c].dtype}")
# Out:
# la quantité de données est : (6675, 14)
# nom des colones : ['date', 'titre', 'budget', 'recette', 'duree', 'genres', 'realisateur', 'casting', 'compagnies_production', 'suite', 'production_countries', 'langues', 'vote_average', 'vote_count']
# le format de date est : datetime64[ns]
# le format de titre est : object
# le format de budget est : int64
# le format de recette est : int64
# le format de duree est : int64
# le format de genres est : object
# le format de realisateur est : object
# le format de casting est : object
# le format de compagnies_production est : object
# le format de suite est : int64
# le format de production_countries est : object
# le format de langues est : object
# le format de vote_average est : float64
# le format de vote_count est : int64

# %% [markdown]
# ligne avec la date la plus récente

# %%
df_update_v3[df_update_v3.date == df_update_v3.date.max()]
# Out:
#            date              titre  budget  recette  duree             genres  \
# 6674 2022-12-23  No One Stays Good   16000    20000     70  [Drama, Thriller]
#
#              realisateur                                            casting  \
# 6674  [Antonio Cavallos]  [Cody Martin, Bryce Martin, Karla Martin, Rand...
#
#      compagnies_production  suite production_countries langues  vote_average  \
# 6674        [Impact Films]      1                 [US]    [en]           0.0
#
#       vote_count
# 6674           0

# %% [markdown]
# ligne avec la plus ancienne date

# %%
df_update_v3[df_update_v3.date == df_update_v3.date.min()]
# Out:
#            date             titre  budget  recette  duree          genres  \
# 6625 1913-11-24  Traffic in Souls    5700  1800000     88  [Crime, Drama]
#
#                 realisateur  \
# 6625  [George Loane Tucker]
#
#                                                 casting  \
# 6625  [Jane Gail, Ethel Grandin, William H. Turner, ...
#
#               compagnies_production  suite production_countries   langues  \
# 6625  [Independent Moving Pictures]      1                 [US]  [en, xx]
#
#       vote_average  vote_count
# 6625           5.5          17

# %% [markdown]
# tableau des lignes avec le plus grand et le plus petit budget

# %%
df_update_v3[(df_update_v3.budget == df_update_v3.budget.max()) | (df_update_v3.budget == df_update_v3.budget.min())]
# Out:
#            date                                              titre     budget  \
# 494  2011-05-14        Pirates of the Caribbean: On Stranger Tides  380000000
# 2581 2012-12-28                               Bojhena Shey Bojhena          1
# 2913 2003-01-01  Latham Entertainment Presents: An All New Come...          1
# 4206 2018-01-16                                      The Lucky Man          1
# 4529 1997-01-05                           Kys, kærlighed og kroner          1
# 4947 2016-07-29                                       Sesh Sangbad          1
# 5023 2015-12-04               Single Dad 2: A Single Dad Christmas          1
# 5394 2019-07-09                                   Perfect, I Think          1
# 5480 1997-12-30                                       Little Ghost          1
# 5520 2019-04-21                                       Precognition          1
# 5521 2019-08-18                                  You're in Trouble          1
# 5522 2019-08-24                                            Assumed          1
# 5523 2019-08-25                          You Know What's Funny...?          1
# 5689 2020-02-17                                            Mothman          1
# 5690 2018-08-09                                             Malawi          1
# 5717 2020-06-19                                The Year of The Day          1
# 5763 2018-12-21                                             Friend          1
# 5764 2005-06-01                                       SobEncomenda          1
# 5765 2020-08-30                                          Me Within          1
# 5777 2020-08-24                                           Brothers          1
# 5796 2020-08-26                                     Is This Water?          1
# 5801 2020-10-15                                         Lipothymia          1
# 5841 2020-11-13                                Rocky Horror Remade          1
# 5910 2019-11-22                                             PePePe          1
# 6117 2014-12-16                                Death of a Criminal          1
# 6170 2021-04-12                                          A Way Out          1
# 6194 2021-08-27                                      Sara & Jaimie          1
# 6599 2021-09-02                                I was not murdered.          1
# 6657 2020-03-20                                        The Package          1
#
#          recette  duree                                             genres  \
# 494   1045713802    137                       [Adventure, Action, Fantasy]
# 2581          15    145                   [Drama, Family, Comedy, Romance]
# 2913          15     90                                           [Comedy]
# 4206          24     98                   [Action, Drama, Science Fiction]
# 4529           1     24                                    [Comedy, Drama]
# 4947           2    120                           [Drama, Thriller, Crime]
# 5023           3      2                                           [Comedy]
# 5394           1     10                                           [Comedy]
# 5480          14     90                       [Family, Fantasy, Adventure]
# 5520           1     20                 [Horror, Thriller, Drama, Mystery]
# 5521           1     25                                           [Comedy]
# 5522           1     32  [Science Fiction, Action, Crime, Drama, Myster...
# 5523           1     11                           [Comedy, Drama, Romance]
# 5689         123      3                                            [Drama]
# 5690         140     80                                      [Documentary]
# 5717           1      5                                            [Drama]
# 5763           1     37                            [Drama, Mystery, Crime]
# 5764           2     75                            [Crime, Comedy, Action]
# 5765           1      5                                   [Mystery, Drama]
# 5777           1     17                                            [Drama]
# 5796           2     11                     [Documentary, History, Family]
# 5801           1      9                                   [Drama, Mystery]
# 5841           1     95  [Horror, Animation, Music, Comedy, Science Fic...
# 5910           1      6                                            [Drama]
# 6117           2      1                                            [Crime]
# 6170           1      7                                            [Drama]
# 6194           1     14                                  [Romance, Comedy]
# 6599           1     82                                   [Drama, Mystery]
# 6657         100      3                        [Thriller, Mystery, Comedy]
#
#                    realisateur  \
# 494             [Rob Marshall]
# 2581         [Raj Chakraborty]
# 2913           [Jerry Gerrard]
# 4206  [Norman Gregory McGuire]
# 4529        [Louise Andreasen]
# 4947            [Pallav Gupta]
# 5023           [Ethan Johnson]
# 5394             [Chelle Reik]
# 5480            [Linda Shayne]
# 5520            [Jesse Fraire]
# 5521         [Ricky Rodriguez]
# 5522         [Michael D. Head]
# 5523      [Carlos De La Torre]
# 5689            [Ben McMorran]
# 5690            [Ben McMorran]
# 5717               [G.D Stami]
# 5763              [Lukas Koch]
# 5764   [Thiago Amaral Ribeiro]
# 5765               [G.D Stami]
# 5777                [CZ Oster]
# 5796         [Craigen Z Oster]
# 5801      [Alex Trincado Haro]
# 5841            [Katie Palino]
# 5910           [Ricky Gunarto]
# 6117           [Titus Meadows]
# 6170             [Ahmed Nazif]
# 6194       [Nicole Toporowski]
# 6599              [Adam Hobbs]
# 6657            [Arman Taheri]
#
#                                                 casting  \
# 494   [Johnny Depp, Penélope Cruz, Geoffrey Rush, Ia...
# 2581  [Soham Chakraborty, Mimi Chakraborty, Abir Cha...
# 2913  [Sommore, Bruce Bruce, J. Anthony Brown, Earth...
# 4206  [Jesse James, Mariana Paola Vicente, Burton Gi...
# 4529  [Peter Reichhardt, Trine Dyrholm, Ulrich Thomsen]
# 4947  [Srabanti Chatterjee, Moushumi Chaterjee, Part...
# 5023                                       [Rayce Cook]
# 5394  [Rhys Smith, Hannah Schroter, David Campbell, ...
# 5480  [Kristina Wayborn, Jim Fitzpatrick, Sally Kirk...
# 5520  [Tessa Leigh Mauer, Sherrie Prose, Greg Thomps...
# 5521  [Alberto Orozco, Alexis Solano, Alfredo Sanche...
# 5522  [Julian Cavett, Jerry Walker, Alfredo Sanchez,...
# 5523  [Valerie Santos, Jon Erik Castro, Jesse Fraire...
# 5689                      [David Hall, Stuart McMorran]
# 5690                      [Finlay Rutter, James Walker]
# 5717                                           [Doomer]
# 5763  [Svenja Theivogt, Lisann Klapp, Daniel Hald, S...
# 5764  [Sanderson Mariquito, Hudson Cotta, Rodrigo Ol...
# 5765                                 [Dylan Anaya, Imi]
# 5777  [Thomas Brumfield, Andrew Brumfield, Brumfield...
# 5796  [Nicole Toporowski, Thomas Brumfield, Final Cu...
# 5801                         [Jana Punsola, Carla Dolç]
# 5841  [Courtney Archard, Luisa Baldino, Zoe Bell, Au...
# 5910        [Ricky Gunarto, Daniel, Vincensius, Debora]
# 6117                                    [Titus Meadows]
# 6170                                      [Anas Alhajj]
# 6194                    [Victor Anderson, Sophia Brown]
# 6599  [Henry Austin, Haman Kallaveh, Katie Carey, El...
# 6657                       [Atossa Alavi, Kimya Taheri]
#
#                                   compagnies_production  suite  \
# 494   [Walt Disney Pictures, Jerry Bruckheimer Films...      4
# 2581                                [SVF Entertainment]      1
# 2913                             [Latham Entertainment]      1
# 4206                                     [Lucky Film, ]      1
# 4529               [M&M Productions, Dansk Novellefilm]      1
# 4947                                         [Eros Now]      1
# 5023                                      [Twat Kicker]      1
# 5394                                [Nonya Productions]      1
# 5480             [Castel Film, Full Moon Entertainment]      1
# 5520  [Tower Productions, JonGon Productions, J. Fri...      1
# 5521                                [Tower Productions]      1
# 5522                                [Tower Productions]      1
# 5523                                [Tower Productions]      1
# 5689                                      [BAM Studios]      1
# 5690                                      [BAM Studios]      1
# 5717                                        [G.D Stami]      1
# 5763                                      [Theory Arts]      1
# 5764                                    [Javali Filmes]      1
# 5765                                        [G.D Stami]      1
# 5777                         [Love Streams Productions]      1
# 5796                         [Love Streams Productions]      1
# 5801                                [Sotos Productions]      1
# 5841                             [The Player's Society]      1
# 5910                                            [ricky]      1
# 6117                            [Macho Man Productions]      1
# 6170                                          [Blushot]      1
# 6194                               [Love Streams Films]      1
# 6599                                   [Hobnob Studios]      1
# 6657                                   [Taheri Studios]      1
#
#      production_countries       langues  vote_average  vote_count
# 494              [GB, US]      [en, es]         6.527       12361
# 2581                 [IN]          [bn]         7.500          12
# 2913                 [US]          [en]         0.000           0
# 4206                 [US]  [en, es, el]         6.200           8
# 4529                 [DK]          [da]         6.000           1
# 4947                 [IN]          [bn]         0.000           0
# 5023                 [US]          [en]        10.000           1
# 5394                 [US]          [en]         0.000           0
# 5480             [RO, US]          [en]         6.100           7
# 5520                 [US]          [en]         0.000           0
# 5521                 [US]          [en]         0.000           0
# 5522                 [US]          [en]         0.000           0
# 5523                 [US]      [en, es]         0.000           0
# 5689                 [GB]          [en]         9.000           3
# 5690             [MW, GB]          [en]        10.000           2
# 5717                 [IN]          [en]         0.000           0
# 5763                 [DE]          [de]        10.000           1
# 5764                 [BR]          [pt]        10.000           1
# 5765                 [IN]          [en]         0.000           0
# 5777                 [US]          [en]         0.000           0
# 5796                 [US]          [en]         0.000           0
# 5801                 [ES]          [ca]        10.000           2
# 5841                 [US]          [en]        10.000           1
# 5910                 [ID]          [id]         7.000           1
# 6117                 [US]          [is]         0.000           0
# 6170                 [EG]      [ar, en]         9.000           1
# 6194                 [US]          [en]         0.000           0
# 6599                 [GB]          [en]         0.000           0
# 6657                 [US]          [en]         0.000           0

# %% [markdown]
# tableau avec la plus grande et la plus petite recette

# %%
df_update_v3[(df_update_v3.recette == df_update_v3.recette.max()) | (df_update_v3.recette == df_update_v3.recette.min())]
# Out:
#            date                                        titre     budget  \
# 1665 2009-12-15                                       Avatar  237000000
# 2948 2014-11-21                          Naaigal Jaakirathai     630000
# 3404 2000-08-11                   MVP: Most Valuable Primate          4
# 3775 2015-09-25  Head Full of Dreams, Heart Full of Promises        100
# 3930 2016-02-06                           ZERO Beyond Limits       1560
# 4529 1997-01-05                     Kys, kærlighed og kroner          1
# 5394 2019-07-09                             Perfect, I Think          1
# 5520 2019-04-21                                 Precognition          1
# 5521 2019-08-18                            You're in Trouble          1
# 5522 2019-08-24                                      Assumed          1
# 5523 2019-08-25                    You Know What's Funny...?          1
# 5717 2020-06-19                          The Year of The Day          1
# 5763 2018-12-21                                       Friend          1
# 5765 2020-08-30                                    Me Within          1
# 5777 2020-08-24                                     Brothers          1
# 5801 2020-10-15                                   Lipothymia          1
# 5841 2020-11-13                          Rocky Horror Remade          1
# 5910 2019-11-22                                       PePePe          1
# 6073 2021-03-27                               Life and Death         10
# 6170 2021-04-12                                    A Way Out          1
# 6194 2021-08-27                                Sara & Jaimie          1
# 6227 2021-04-21                                    Pulsating        100
# 6579 2021-11-13                              My Dear Spectre        500
# 6589 2021-12-10                                     Monster?        100
# 6599 2021-09-02                          I was not murdered.          1
# 6601 2021-12-23                  The Fright Before Christmas         10
# 6614 2021-03-09               The 4.5 'Flim On Film' Podcast         20
# 6635 2022-02-04                                The Interview          5
# 6672 2015-01-22                         Jeff Movie 3: Part 1         10
#
#          recette  duree                                             genres  \
# 1665  2920357254    162      [Action, Adventure, Fantasy, Science Fiction]
# 2948           1    126                         [Thriller, Action, Comedy]
# 3404           1     85                                   [Comedy, Family]
# 3775           1     10                                      [Documentary]
# 3930           1     60                 [Action, Adventure, Comedy, Crime]
# 4529           1     24                                    [Comedy, Drama]
# 5394           1     10                                           [Comedy]
# 5520           1     20                 [Horror, Thriller, Drama, Mystery]
# 5521           1     25                                           [Comedy]
# 5522           1     32  [Science Fiction, Action, Crime, Drama, Myster...
# 5523           1     11                           [Comedy, Drama, Romance]
# 5717           1      5                                            [Drama]
# 5763           1     37                            [Drama, Mystery, Crime]
# 5765           1      5                                   [Mystery, Drama]
# 5777           1     17                                            [Drama]
# 5801           1      9                                   [Drama, Mystery]
# 5841           1     95  [Horror, Animation, Music, Comedy, Science Fic...
# 5910           1      6                                            [Drama]
# 6073           1      9                                 [Comedy, Thriller]
# 6170           1      7                                            [Drama]
# 6194           1     14                                  [Romance, Comedy]
# 6227           1      4                  [Thriller, Drama, Music, Mystery]
# 6579           1      6                                   [Romance, Drama]
# 6589           1      9                           [Horror, Romance, Drama]
# 6599           1     82                                   [Drama, Mystery]
# 6601           1      3                                         [Thriller]
# 6614           1     51                                           [Comedy]
# 6635           1      2                                    [Comedy, Drama]
# 6672           1      2                                 [Thriller, Action]
#
#                                             realisateur  \
# 1665                                    [James Cameron]
# 2948                             [Shakti Soundar Rajan]
# 3404                                     [Robert Vince]
# 3775                                        [Renny Ray]
# 3930                                     [Beis Shabani]
# 4529                                 [Louise Andreasen]
# 5394                                      [Chelle Reik]
# 5520                                     [Jesse Fraire]
# 5521                                  [Ricky Rodriguez]
# 5522                                  [Michael D. Head]
# 5523                               [Carlos De La Torre]
# 5717                                        [G.D Stami]
# 5763                                       [Lukas Koch]
# 5765                                        [G.D Stami]
# 5777                                         [CZ Oster]
# 5801                               [Alex Trincado Haro]
# 5841                                     [Katie Palino]
# 5910                                    [Ricky Gunarto]
# 6073                                    [SirChancealot]
# 6170                                      [Ahmed Nazif]
# 6194                                [Nicole Toporowski]
# 6227                                    [Nathan Cowles]
# 6579                              [M. Ridzky Ramadhani]
# 6589                                   [Brinceton Baum]
# 6599                                       [Adam Hobbs]
# 6601  [Maryn Zaborowsky, Trever Capien, Lily William...
# 6614                                    [James Horsley]
# 6635                                      [Camdan Mead]
# 6672                                      [Jack McGurn]
#
#                                                 casting  \
# 1665  [Sam Worthington, Zoe Saldaña, Sigourney Weave...
# 2948  [Sibiraj, Arundhathi Nair, Manobala, Balaji Pa...
# 3404  [Kevin Zegers, Jamie Renée Smith, Alexa Benett...
# 3775  [Inna Levian, Alise Sheli Orsa, Davek, Denis K...
# 3930  [Marigon Zyberi, Valenti Shabani, Siok Tosuni,...
# 4529  [Peter Reichhardt, Trine Dyrholm, Ulrich Thomsen]
# 5394  [Rhys Smith, Hannah Schroter, David Campbell, ...
# 5520  [Tessa Leigh Mauer, Sherrie Prose, Greg Thomps...
# 5521  [Alberto Orozco, Alexis Solano, Alfredo Sanche...
# 5522  [Julian Cavett, Jerry Walker, Alfredo Sanchez,...
# 5523  [Valerie Santos, Jon Erik Castro, Jesse Fraire...
# 5717                                           [Doomer]
# 5763  [Svenja Theivogt, Lisann Klapp, Daniel Hald, S...
# 5765                                 [Dylan Anaya, Imi]
# 5777  [Thomas Brumfield, Andrew Brumfield, Brumfield...
# 5801                         [Jana Punsola, Carla Dolç]
# 5841  [Courtney Archard, Luisa Baldino, Zoe Bell, Au...
# 5910        [Ricky Gunarto, Daniel, Vincensius, Debora]
# 6073  [Emery Gischler, SirChancealot, Connor (from S...
# 6170                                      [Anas Alhajj]
# 6194                    [Victor Anderson, Sophia Brown]
# 6227                                   [Jordan Belcher]
# 6579                                     [Tamara Putri]
# 6589                        [Juan Suarez, Olivia Watts]
# 6599  [Henry Austin, Haman Kallaveh, Katie Carey, El...
# 6601  [Maryn Zaborowsky, Trever Capien, Lily William...
# 6614  [Patrick Monahan, James Horsley, Guy Barnsley,...
# 6635                     [Chloe Braatz, Katie Cambpell]
# 6672  [Jeff T. Ball, Matthew Stewart, Ewan Macfarlan...
#
#                                   compagnies_production  suite  \
# 1665  [20th Century Fox, Ingenious Media, Dune Enter...      4
# 2948                           [Nathambal Film Factory]      1
# 3404  [Keystone Family Pictures, Funky Monkey Produc...      1
# 3775                             [Art Attack Manifesto]      1
# 3930                                [SEHR, Aceldoredon]      1
# 4529               [M&M Productions, Dansk Novellefilm]      1
# 5394                                [Nonya Productions]      1
# 5520  [Tower Productions, JonGon Productions, J. Fri...      1
# 5521                                [Tower Productions]      1
# 5522                                [Tower Productions]      1
# 5523                                [Tower Productions]      1
# 5717                                        [G.D Stami]      1
# 5763                                      [Theory Arts]      1
# 5765                                        [G.D Stami]      1
# 5777                         [Love Streams Productions]      1
# 5801                                [Sotos Productions]      1
# 5841                             [The Player's Society]      1
# 5910                                            [ricky]      1
# 6073                      [Wandering Robot Productions]      1
# 6170                                          [Blushot]      1
# 6194                               [Love Streams Films]      1
# 6227                               [The Boys of Willow]      1
# 6579                                [Parcstar Assembly]      1
# 6589                                 [Brinceton Vision]      1
# 6599                                   [Hobnob Studios]      1
# 6601                                           [iMovie]      1
# 6614                           [Colourline Productions]      1
# 6635                                      [Warren Tech]      1
# 6672                                 [One Sock Wonders]      1
#
#      production_countries       langues  vote_average  vote_count
# 1665             [US, GB]      [en, es]         7.526       26386
# 2948                 [IN]          [ta]         6.700           7
# 3404             [CA, US]          [en]         4.800          67
# 3775             [CZ, IN]      [en, ur]        10.000           1
# 3930                 [AL]  [sq, en, ja]        10.000           1
# 4529                 [DK]          [da]         6.000           1
# 5394                 [US]          [en]         0.000           0
# 5520                 [US]          [en]         0.000           0
# 5521                 [US]          [en]         0.000           0
# 5522                 [US]          [en]         0.000           0
# 5523                 [US]      [en, es]         0.000           0
# 5717                 [IN]          [en]         0.000           0
# 5763                 [DE]          [de]        10.000           1
# 5765                 [IN]          [en]         0.000           0
# 5777                 [US]          [en]         0.000           0
# 5801                 [ES]          [ca]        10.000           2
# 5841                 [US]          [en]        10.000           1
# 5910                 [ID]          [id]         7.000           1
# 6073                 [US]          [en]         0.000           0
# 6170                 [EG]      [ar, en]         9.000           1
# 6194                 [US]          [en]         0.000           0
# 6227                 [US]          [en]         0.000           0
# 6579                 [ID]          [en]         9.000           1
# 6589                 [US]          [en]         0.000           0
# 6599                 [GB]          [en]         0.000           0
# 6601                 [US]          [en]        10.000           1
# 6614                 [GB]          [en]         0.000           0
# 6635                 [US]          [en]        10.000           1
# 6672                 [GB]          [en]         9.000           1

# %%
df_update_v3[(df_update_v3.duree == df_update_v3.duree.max()) | (df_update_v3.duree == df_update_v3.duree.min())]
# Out:
#            date                                             titre    budget  \
# 4336 2010-07-07                                            Carlos  18000000
# 4910 2000-01-01                                     Le savon lave      2883
# 5528 2019-10-31                             Cómo regar un girasol        50
# 6117 2014-12-16                               Death of a Criminal         1
# 6226 1998-02-03                        Science Please! : The Wind         3
# 6230 2001-10-01                              Why Is the Sky Blue?      7027
# 6231 2001-01-01                                              Fire      5032
# 6565 2000-01-01  Science Please! : The Internal Combustion Engine    300996
# 6566 1998-01-01              Science Please! : The Force of Water     43134
# 6567 1998-01-01            Science Please! : Wheel Meets Friction      5477
# 6631 2019-07-15                                             Homer        80
#
#       recette  duree                             genres  \
# 4336   871279    339  [Crime, Drama, Thriller, History]
# 4910     2883      1                [Animation, Family]
# 5528      150      1                          [Fantasy]
# 6117        2      1                            [Crime]
# 6226        3      1                [Family, Animation]
# 6230     7027      1         [Animation, Family, Music]
# 6231     5032      1                [Animation, Comedy]
# 6565   300996      1                        [Animation]
# 6566    43134      1                        [Animation]
# 6567     5477      1                        [Animation]
# 6631       10      1                [Comedy, Animation]
#
#                           realisateur  \
# 4336                [Olivier Assayas]
# 4910            [Sylvain Charbonneau]
# 5528                 [Joaquín Cariño]
# 6117                  [Titus Meadows]
# 6226  [Claude Cloutier, Martin Barry]
# 6230            [Sylvain Charbonneau]
# 6231            [Sylvain Charbonneau]
# 6565                [Claude Cloutier]
# 6566                [Claude Cloutier]
# 6567                [Claude Cloutier]
# 6631               [Gustavo Riquelme]
#
#                                                 casting  \
# 4336  [Edgar Ramírez, Alexander Scheer, Nora Waldstä...
# 4910                                       [Rick Jones]
# 5528                                  [Aldair Enríquez]
# 6117                                    [Titus Meadows]
# 6226                                       [Rick Jones]
# 6230                                       [Rick Jones]
# 6231                                       [Rick Jones]
# 6565                                       [Rick Jones]
# 6566                                       [Rick Jones]
# 6567                                       [Rick Jones]
# 6631                                 [Gustavo Riquelme]
#
#                                   compagnies_production  suite  \
# 4336  [ARTE France Cinéma, Canal+, CNC, PROCIREP, St...      1
# 4910                                        [ONF | NFB]      1
# 5528                  [ESPERA Y DESESPERA Espectáculos]      1
# 6117                            [Macho Man Productions]      1
# 6226                                        [ONF | NFB]      1
# 6230                                        [ONF | NFB]      1
# 6231                                        [ONF | NFB]      1
# 6565                                        [ONF | NFB]      1
# 6566                                        [ONF | NFB]      1
# 6567                                        [ONF | NFB]      1
# 6631                                [The Amazing Brick]      1
#
#      production_countries                           langues  vote_average  \
# 4336             [DE, FR]  [fr, de, en, es, ar, hu, ja, ru]         6.981
# 4910                 [CA]                              [en]        10.000
# 5528                 [MX]                              [es]        10.000
# 6117                 [US]                              [is]         0.000
# 6226                 [CA]                              [en]        10.000
# 6230                 [CA]                              [en]        10.000
# 6231                 [CA]                              [en]         0.000
# 6565                 [CA]                              [en]         0.000
# 6566                 [CA]                              [en]         0.000
# 6567                 [CA]                              [en]         0.000
# 6631             [CL, US]                              [en]         0.000
#
#       vote_count
# 4336         156
# 4910           1
# 5528           1
# 6117           0
# 6226           1
# 6230           1
# 6231           0
# 6565           0
# 6566           0
# 6567           0
# 6631           0

# %%
def drop_useless_lines(df):
    index_names = df[(df['budget'] < 300000) | (df['recette'] < 300000) | (df['duree'] < 60) | (df['duree'] > 210) | (df_update_v3['casting'].map(len) < 5) | (df_update_v3['date'] < pd.to_datetime('2000-01-01'))].index
    df_update_v4 = df.drop(index_names, axis = 0)
    df_update_v4.reset_index(drop = True, inplace = True)
    return df_update_v4

# %%
df_update_v4 = drop_useless_lines(df_update_v3)
print(df_update_v4.shape)
df_update_v4.head()
# Out:
# (3586, 14)
#         date                                titre     budget    recette  \
# 0 2014-11-12                   Dumb and Dumber To   40000000  169837010
# 1 2014-03-20  Captain America: The Winter Soldier  170000000  714766572
# 2 2012-03-15                    Тот ещё Карлосон!    4000000    9938268
# 3 2006-05-19                          See No Evil    8000000   18707966
# 4 2003-10-23                         Brother Bear  128000000  250397798
#
#    duree                                genres  \
# 0    110                              [Comedy]
# 1    136  [Action, Adventure, Science Fiction]
# 2     80             [Comedy, Fantasy, Family]
# 3     84                    [Horror, Thriller]
# 4     85        [Adventure, Animation, Family]
#
#                         realisateur  \
# 0  [Bobby Farrelly, Peter Farrelly]
# 1        [Anthony Russo, Joe Russo]
# 2                [Sarik Andreasyan]
# 3                    [Gregory Dark]
# 4     [Aaron Blaise, Robert Walker]
#
#                                              casting  \
# 0  [Jim Carrey, Jeff Daniels, Laurie Holden, Rach...
# 1  [Chris Evans, Scarlett Johansson, Sebastian St...
# 2  [Mikhail Galustyan, Igor Vernik, Mariya Semkin...
# 3  [Glenn Jacobs, Christina Vidal, Luke Pegler, C...
# 4  [Joaquin Phoenix, Jeremy Suarez, Jason Raize, ...
#
#                                compagnies_production  suite  \
# 0  [New Line Cinema, Universal Pictures, Conundru...      3
# 1                                   [Marvel Studios]      2
# 2                                     [Enjoy Movies]      1
# 3                    [Lions Gate Films, WWE Studios]      1
# 4                    [Walt Disney Feature Animation]      1
#
#   production_countries       langues  vote_average  vote_count
# 0                 [US]          [en]         5.542        2740
# 1                 [US]          [en]         7.678       16638
# 2                 [RU]          [ru]         3.400          24
# 3             [AU, US]          [en]         5.400         530
# 4                 [US]  [hr, en, iu]         7.244        4661

# %%
df_update_v4.to_csv("data\df_update_v4.csv")

# %% [markdown]
# ### Fonction qui permet de transformer les noms des genres en numéro

# %%
liste_genres = ['Comedy', 'Drama', 'Horror', 'Thriller', 'Action', 'Adventure', 'Science Fiction', 'Fantasy', 'Family', 'Crime', 'Romance', 'Mystery', 'Animation', 'War', 'Music', 'Western', 'History', 'Documentary', 'TV Movie']
liste_nb = range(len(liste_genres))

dataset_genres = pd.DataFrame(liste_nb, liste_genres, columns=['genre_number'])
dataset_genres.head()
# Out:
#           genre_number
# Comedy               0
# Drama                1
# Horror               2
# Thriller             3
# Action               4
